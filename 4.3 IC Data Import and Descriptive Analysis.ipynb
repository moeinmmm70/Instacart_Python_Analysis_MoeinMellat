# %% [markdown]
# # 01. Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Define the project path and Import “orders.csv”

path = r'C:\Users\moein\anaconda3\04-2025 Achievement 4 - Python Fundamentals\02 Data\Original Data'
vars_list = ['order_id', 'user_id', 'order_number', 
             'order_dow', 'order_hour_of_day', 'days_since_prior_order']
df = pd.read_csv(os.path.join(path, 'orders.csv'), usecols=vars_list)

# %%
# Print First 5 Rows of df

df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# Import “products.csv” as df_prods

df_prods = pd.read_csv(os.path.join(path, 'products.csv'))

# %%
# Print Rows from df_prods

# First 20 rows
df_prods.head(20)

# Last 35 rows
df_prods.tail(35)
# Out:
#        product_id                                       product_name  \
# 49658       49654                   Teriyaki Sauce, Sesame, Original
# 49659       49655                                        Apple Cider
# 49660       49656                         Masada Kosher Pocket Bread
# 49661       49657                                  Cabernet Tomatoes
# 49662       49658                         Brie with Herbs Foil Wedge
# 49663       49659                            Organic Creamed Coconut
# 49664       49660                        Professionals Sleek Shampoo
# 49665       49661                                              Porto
# 49666       49662                       Bacon Cheddar Pretzel Pieces
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
# 49668       49664                     Lemon Cayenne Drinking Vinegar
# 49669       49665      Super Dark Coconut Ash & Banana Chocolate Bar
# 49670       49666                      Ginger Snaps Snacking Cookies
# ...

# %%
# Print Column Names

df_prods.columns
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
# Print Shape (Rows & Columns)

df_prods.shape
# Out:
# (49693, 5)

# %%
# Max value of “aisle_id”

df_prods['aisle_id'].max()
# Out:
# 134

# %%
# Data type of “department_id”

df_prods['department_id'].dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### What’s the maximum value of the “aisle_id” column?
# The maximum value of the `aisle_id` column is 134.
#
# ### What’s the data type of the “department_id” column?
# The `department_id` column is of data type `int64`, which means it stores integer values.
