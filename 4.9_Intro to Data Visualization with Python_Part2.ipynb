# %% [markdown]
# ### 🔹 Step 1: Setup & Load Data

# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
import matplotlib.pyplot as plt

# Define file path
file_path = r"C:\Users\moein\anaconda3\4 - Python Fundamentals\02 Data\Prepared Data\ords_prods_cust_merge.pkl"

# Load the dataframe
df = pd.read_pickle(file_path)

# %%
# Preview the dataset
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     0.0         196                  1          0   both
# 1                     0.0       14084                  2          0   both
# 2                     0.0       12427                  3          0   both
# 3                     0.0       26088                  4          0   both
# 4                     0.0       26405                  5          0   both
#
# ...

# %% [markdown]
# ### 🔹 Step 2: Create One of Each Plot Type

# %% [markdown]
# #### Bar Chart (order_hour_of_day)

# %%
# Create bar plot of orders by hour of day
df['order_hour_of_day'].value_counts().sort_index().plot.bar()

# Set plot title and labels
plt.title('Orders by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Orders')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\orders_by_hour.png')

# Show the plot
plt.show()

# %% [markdown]
# #### Histogram (age)

# %%
# Create histogram of age
df['age'].plot.hist(bins=25)

# Set plot title and labels
plt.title('Age Distribution')
plt.xlabel('Age')
plt.savefig('Age_distribution.png')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\histogram_age.png')

plt.show()

# %% [markdown]
# #### Scatterplot (income vs. age)

# %%
# Create scatterplot
sns.scatterplot(x='age', y='income', data=df)

# Set plot title and labels
plt.title('Income vs Age')
plt.xlabel('Age')
plt.ylabel('Income')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\income_vs_age.png')

# Show the plot
plt.show()

# %% [markdown]
# ####  Line Chart Sample

# %%
# Sample subset of 10,000 rows
sample = df.sample(n=10000, random_state=42)

# Group and calculate mean
line_data = sample.groupby('order_hour_of_day').mean(numeric_only=True)

# Plot the line chart
line_data['prices'].plot.line()
plt.title('Average Price by Hour of Day (Sample)')
plt.xlabel('Hour of Day')
plt.ylabel('Average Price')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\avg_price_by_hour.png')

# Show plot
plt.show()

# %% [markdown]
# ### 🔹 Step 3: Histogram – order_hour_of_day

# %%
# Create histogram
df['order_hour_of_day'].plot.hist(bins=24)

# Set plot title and labels
plt.title('Distribution of Orders by Hour of Day')
plt.xlabel('Hour')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\order_hour_histogram.png')

# Show plot
plt.show()

# %% [markdown]
# The histogram "**Distribution of Orders by Hour of Day**" reveals the following:
#
# - Order activity is heavily concentrated between 9 AM and 5 PM, with a noticeable peak between 10 AM and 3 PM, where frequency reaches its maximum (~2.8 million orders).
#
# - There are very few orders placed overnight, especially between 12 AM and 6 AM, indicating minimal customer engagement during those hours.
#
# - After 5 PM, there's a gradual decline in order volume, showing reduced customer activity into the evening.
#
# This distribution suggests that Instacart customers are most active during standard daytime hours, likely reflecting shopping behavior aligned with work breaks, lunch hours, or general household routines.

# %% [markdown]
# ### 🔹 Step 4: Bar Chart – loyalty_flag

# %%
# Create bar chart
df['loyalty_flag'].value_counts().plot.bar()

# Set plot title and lables
plt.title('Order Distribution by Customer Loyalty')
plt.xlabel('Loyalty Group')
plt.ylabel('Number of Orders')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\loyalty_flag_bar.png')

# Show plot
plt.show()

# %% [markdown]
# ### 🔹 Step 5: Line Chart – prices by order_hour_of_day (Sampled)

# %%
# Sample subset of 100,000 rows
sample = df.sample(n=100000, random_state=42)

# Group and calculate mean
line_data = sample.groupby('order_hour_of_day')['prices'].mean()

# Plot the line chart
line_data.plot.line()
plt.title('Average Spend by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Price')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\avg_spend_by_hour.png')

# Show plot
plt.show()

# %% [markdown]
# ### 🔹 Step 6: Line Chart – Age vs Number of Dependents

# %%
# Create the grouped line plot
age_dependents = df.groupby('age')['n_dependants'].mean()
age_dependents.plot.line()

# Customize the plot
plt.title('Average Number of Dependents by Age')
plt.xlabel('Age')
plt.ylabel('Average Number of Dependents')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\age_vs_dependents.png')

# Show plot
plt.show()

# %% [markdown]
# ### Average Number of Dependents by Age
#
# The line chart displays the relationship between customer age and their reported number of dependents.
#
# **Interpretation:**
#
# - Overall, the average number of dependents remains relatively stable across age groups, generally hovering around 1.5.
# - There is no strong or consistent trend indicating that either younger or older age groups have significantly more or fewer dependents.
# - Minor fluctuations appear across the age spectrum, suggesting some variability, but these seem random and not indicative of a meaningful pattern.
# - The chart may also reflect limitations in the data granularity or noise in customer reporting.
#
# **Insight for Marketing:**
#
# This suggests that **age alone might not be a strong predictor** of family size in this customer dataset. If the marketing team is targeting based on family status, they may want to incorporate additional demographic variables (like marital status or income) for better segmentation.

# %% [markdown]
# ### 🔹 Step 7: Scatterplot – Age vs Income

# %%
# Create scatterplot
sns.scatterplot(x='age', y='income', data=df)

# Customize the plot
plt.title('Income Distribution by Age')
plt.xlabel('Age')
plt.ylabel('Income')

# Save plot
plt.savefig(r'C:\Users\moein\anaconda3\4 - Python Fundamentals\04 Analysis\4.9\age_vs_income.png')

# Show plot
plt.show()

# %% [markdown]
# ### Income Distribution by Age
#
# The scatterplot displays the relationship between customer age and their income levels.
#
# From the chart, we observe that:
# - Income levels are widely dispersed across all age groups.
# - There is a dense horizontal band of data points around the lower income ranges, particularly between €20,000 and €200,000, suggesting that most customers fall within this income bracket regardless of age.
# - Higher income values (above €400,000) appear across various age groups but become more common among customers aged 40 and older.
# - There is no clear linear correlation between age and income; income distribution appears random with respect to age, though older individuals tend to show a slightly broader income spread.
#
# This suggests that marketing campaigns targeting high-income customers should not be based solely on age.
